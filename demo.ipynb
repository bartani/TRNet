# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from test import enhance_image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from test import enhance_image
#
# ImportError: cannot import name 'enhance_image' from 'test' (c:\Users\Bartani\anaconda3\Lib\test\__init__.py)

# %%
# your_instruction = "Can you help clean up this picture? The noise is ruining the details." # task noise
your_instruction = "Cette photo est couverte de gouttes de pluie. Pouvez-vous les supprimer pour que ce soit clair" # rain noise
# your_instruction = "Restore the brilliant orange glow of the tube sponges nestled among the reef rocks." # task WUIR
Image_path = "data/test images/single degradation/data-2.png"

save_path = "outcomes/gen/data-2.png"

# %%
target_task = enhance_image(Image_path, your_instruction, img_enc, txt_enc, token, model, get_Points(), save_path)

# %%
# print("Based on your input image and instruction, TRNet applaied", tasks[target_task], "restoration on the input image")
target_task.shape
# Out:
# torch.Size([8, 512])
